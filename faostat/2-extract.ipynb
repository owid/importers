# %% [markdown]
# # Extract the data into CSV files

# %% [markdown]
# ## Dependencies & global variables

# %%
import sys
sys.path.append("..")

import pandas as pd
import os
from tqdm import tqdm
import datetime
import json
from glob import glob
import zipfile

DATA_PATH = 'input/FAOSTAT'
DATA_UNZIP_PATH = 'input/tmp'
METADATA_PATH = 'input/metadata'
OUTPUT_PATH = 'output/'
STANDARDIZATION_PATH = 'standardization/'

# %% [markdown]
# ## Load the metadata

# %%
def read_json_file(file_path):
    with open(file_path, 'r') as json_file:
        return json.load(json_file)

# %%
def get_name_from_path(file_path):
    return file_path.split("/")[-1]

# %%
metadata_by_code = read_json_file(os.path.join(METADATA_PATH, 'metadata_by_code.json'))
datasets = read_json_file(os.path.join(METADATA_PATH, 'datasets.json'))

# In order to match the metadata against our bulk downloaded files, we need to 
for dataset in datasets:
    dataset['FileName'] = get_name_from_path(dataset['FileLocation'])

# %% [markdown]
# ### Exclude the datasets we can't support

# %% [markdown]
# We don't support these because they either include a **monthly breakdown** or because they have **too many breakdowns** and are not worth the effort.

# %%
codes_to_exclude = ['PM', 'OA', 'CP', 'ET', 'PA', 'HS', 'TM', 'EA', 'FA', 'FT']
datasets = [d for d in datasets if d['DatasetCode'] not in codes_to_exclude]

# %% [markdown]
# ### Ensure the metadata is correctly loaded

# %%
pd.DataFrame(datasets)
# Out:
#    CompressionFormat                             Contact DatasetCode  \
# 0                zip  Nienke Beintema and Gert-Jan Stads          AE
# 1                zip  Nienke Beintema and Gert-Jan Stads          AF
# 2                zip                    Mr. Salar Tayyib          BC
# 3                zip                    Mr. Salar Tayyib          BL
# 4                zip                    Mr. Salar Tayyib          CC
# 5                zip                   Mukesh Srivastava        CISP
# 6                zip                    Mr. Salar Tayyib          CL
# 7                zip               Mr. Mukesh Srivastava          CS
# 8                zip           Francesco Nicola Tubiello          EF
# 9                zip           Francesco Nicola Tubiello          EI
# 10               zip           Francesco Nicola Tubiello          EK
# 11               zip           Francesco Nicola Tubiello          EL
# 12               zip           Francesco Nicola Tubiello          EM
# 13               zip           Francesco Nicola Tubiello         EMN
# 14               zip           Francesco Nicola Tubiello          EP
# 15               zip                    Mr. Salar Tayyib         FBS
# 16               zip                    Mr. Salar Tayyib        FBSH
# 17               zip    Mukesh Srivastava; Eun Jeong Lee         FDI
# 18               zip                Arvydas Lebedys (Mr)          FO
# 19               zip                       Carlo Cafiero          FS
# 20               zip           Francesco Nicola Tubiello          GA
# 21               zip          Francesco Nicola Tubiello.          GB
# 22               zip           Francesco Nicola Tubiello          GC
# 23               zip           Francesco Nicola Tubiello          GE
# 24               zip           Francesco Nicola Tubiello          GF
# 25               zip           Francesco Nicola Tubiello          GG
# 26               zip           Francesco Nicola Tubiello          GH
# 27               zip           Francesco Nicola Tubiello          GI
# 28               zip           Francesco Nicola Tubiello          GL
# 29               zip           Francesco Nicola Tubiello          GM
# ..               ...                                 ...         ...
# 34               zip           Francesco Nicola Tubiello          GU
# 35               zip           Francesco Nicola Tubiello          GV
# 36               zip           Francesco Nicola Tubiello          GY
# 37               zip       Piero Conforti, Eun Jeong Lee          IC
# 38               zip                      Piero Conforti          IG
# 39               zip           Francesco Nicola Tubiello          LC
# 40               zip                   Mr Piero Conforti          MK
# 41               zip                      Piero Conforti          OE
# 42               zip                   Mr Piero Conforti          PD
# 43               zip                       Eun Jeong LEE          PE
# 44               zip                       Sangita Dubey          PI
# 45               zip                       Sangita Dubey          PP
# 46               zip                    Mr. Salar Tayyib          QA
# 47               zip                    Mr. Salar Tayyib          QC
# 48               zip                    Mr. Salar Tayyib          QD
# 49               zip                    Mr. Salar Tayyib          QI
# 50               zip                    Mr. Salar Tayyib          QL
# 51               zip                    Mr. Salar Tayyib          QP
# 52               zip                    Mr. Salar Tayyib          QV
# 53               zip           Francesco Nicola Tubiello          RA
# 54               zip           Francesco Nicola Tubiello         RFB
# 55               zip           Francesco Nicola Tubiello         RFN
# 56               zip           Francesco Nicola Tubiello          RL
# 57               zip                       Sangita Dubey          RM
# 58               zip           Francesco Nicola Tubiello          RP
# 59               zip           Francesco Nicola Tubiello          RT
# 60               zip                                None          RY
# 61               zip                    Mr. Salar Tayyib          TA
# 62               zip                    Mr. Salar Tayyib          TI
# 63               zip                    Mr. Salar Tayyib          TP
#
#                                    DatasetDescription  \
# 0   ASTI collects primary time-series data on agri...
# 1   ASTI collects primary time-series data on agri...
# 2   Commodity balances show balances of food and a...
# 3   Food supply data is some of the most important...
# 4   Food supply data is some of the most important...
# 5   The Country Investment Statistics Profile doma...
# 6   Food supply data is some of the most important...
# 7   As part of the FAO Agriculture Capital Stock (...
# 8   The data describe the use of chemical and mine...
# 9   Intensities of greenhouse gas (GHG) emissions ...
# 10  The Livestock Patterns domain of the FAOSTAT A...
# 11  The Agri-environmental IndicatorsLand Use dom...
# 12  The FAOSTAT Emissions shares domain of FAOSTAT...
# 13  The Livestock Manure domain under the FAOSTAT ...
# 14  Agri-environmental indicator on the Use of pes...
# 15  Food Balance Sheet presents a comprehensive pi...
# 16  Food Balance Sheet presents a comprehensive pi...
# 17  All data originates from the United Nations Co...
# 18  The database contains data on the production a...
# 19  For detailed description of the indicators bel...
# 20  Greenhouse gas (GHG) emissions from crop resid...
# 21  Greenhouse Gas (GHG) emissions from burning cr...
# 22  Greenhouse gas (GHG) emissions in the domain "...
# 23  Greenhouse gas (GHG) emissions from enteric fe...
# 24  Annual net CO2 emission/removal from Forest La...
# 25  Greenhouse gas (GHG) emissions in the domain "...
# 26  Greenhouse Gas (GHG) emissions from burning of...
# 27  Greenhouse Gas (GHG) emissions from burning of...
# 28  Land Use Total contains all GHG emissions and ...
# 29  Greenhouse gas (GHG) emissions from manure man...
# ..                                                ...
# 34  GHG emissions from manure applied to soils con...
# 35  The domain Cultivation of Organic soils contai...
# 36  Greenhouse gas (GHG) emissions from synthetic ...
# 37  The Credit to Agriculture dataset provides nat...
# 38  The Statistics Division of FAO collects annual...
# 39  The FAOSTAT domain Land Cover under the Agri-E...
# 40  TheFAOSTAT Macro Indicatorsdatabase provides a...
# 41  The FAOSTAT Employment indicators module conta...
# 42  The FAOSTAT Deflators database provides the fo...
# 43  Annual exchange rates, national currency units...
# 44  Indices of agricultural producer prices that m...
# 45  This sub-domain contains data on Agriculture P...
# 46  The dataset contains the following commodities...
# 47  Crop statistics are recorded for 173 products,...
# 48  The dataset covers the following commodities: ...
# 49  The dataset includes data on gross and net pro...
# 50  The dataset contains the following commodities...
# 51  The dataset covers the following commodities: ...
# 52  The data set includes data on gross and net pr...
# 53  The Fertilizer archive dataset containsinforma...
# 54  The Fertilizers by Product dataset contains in...
# 55  The Fertilizers by Nutrient dataset contains i...
# 56  The FAOSTAT Land Use domain contains data on f...
# 57  Important notice: FAOSTAT database on Agricult...
# 58  The Pesticides Use database includes data on t...
# 59  This domain contains data on pesticides and co...
# 60                                               None
# 61  The food and agricultural trade dataset is col...
# 62  The food and agricultural trade dataset is col...
# 63  The food and agricultural trade dataset is col...
#
#                                           DatasetName  DateUpdate  \
# 0              ASTI R&D Indicators: ASTI-Expenditures  2019-11-11
# 1               ASTI R&D Indicators: ASTI-Researchers  2019-11-11
# 2   Food Balance: Commodity Balances - Crops Prima...  2018-01-16
# 3   Food Balance: Commodity Balances - Livestock a...  2018-01-17
# 4   Food Balance: Food Supply - Crops Primary Equi...  2018-02-05
# 5   Investment: Country Investment Statistics Profile  2018-12-19
# 6   Food Balance: Food Supply - Livestock and Fish...  2018-01-17
# 7                     Macro-Statistics: Capital Stock  2018-09-11
# 8   Agri-Environmental Indicators: Fertilizers ind...  2019-11-22
# 9   Agri-Environmental Indicators: Emissions inten...  2019-11-27
# 10  Agri-Environmental Indicators: Livestock Patterns  2019-04-15
# 11  Agri-Environmental Indicators: Land use indica...  2019-12-04
# 12    Agri-Environmental Indicators: Emissions shares  2016-12-19
# 13    Agri-Environmental Indicators: Livestock Manure  2019-04-29
# 14  Agri-Environmental Indicators: Pesticides indi...  2019-11-15
# 15                    Food Balance: New Food Balances  2019-12-19
# 16  Food Balance: Food Balances (old methodology a...  2017-12-12
# 17        Investment: Foreign Direct Investment (FDI)  2019-11-11
# 18            Forestry: Forestry Production and Trade  2020-02-10
# 19   Food Security: Suite of Food Security Indicators  2019-10-11
# 20             Emissions - Agriculture: Crop Residues  2019-06-10
# 21   Emissions - Agriculture: Burning - Crop Residues  2019-06-10
# 22                     Emissions - Land Use: Cropland  2019-10-31
# 23      Emissions - Agriculture: Enteric Fermentation  2019-06-14
# 24                  Emissions - Land Use: Forest Land  2019-10-31
# 25                    Emissions - Land Use: Grassland  2019-10-31
# 26         Emissions - Agriculture: Burning - Savanna  2019-07-11
# 27            Emissions - Land Use: Burning - Biomass  2019-10-31
# 28               Emissions - Land Use: Land Use Total  2019-10-31
# 29         Emissions - Agriculture: Manure Management  2019-06-14
# ..                                                ...         ...
# 34   Emissions - Agriculture: Manure applied to Soils  2019-06-14
# 35  Emissions - Agriculture: Cultivation of Organi...  2019-07-11
# 36     Emissions - Agriculture: Synthetic Fertilizers  2019-09-16
# 37                  Investment: Credit to Agriculture  2019-11-12
# 38                 Investment: Government Expenditure  2019-10-11
# 39          Agri-Environmental Indicators: Land Cover  2019-06-20
# 40                 Macro-Statistics: Macro Indicators  2019-05-09
# 41                      Inputs: Employment Indicators  2019-03-18
# 42                                  Prices: Deflators  2019-05-09
# 43                    Prices: Exchange rates - Annual  2019-04-19
# 44            Prices: Producer Price Indices - Annual  2019-03-13
# 45                   Prices: Producer Prices - Annual  2019-11-26
# 46                           Production: Live Animals  2020-02-06
# 47                                  Production: Crops  2020-02-06
# 48                        Production: Crops processed  2017-05-17
# 49                     Production: Production Indices  2018-05-22
# 50                      Production: Livestock Primary  2020-02-06
# 51                    Production: Livestock Processed  2017-05-17
# 52       Production: Value of Agricultural Production  2018-11-30
# 53                        Inputs: Fertilizers archive  2018-01-08
# 54                     Inputs: Fertilizers by Product  2019-08-22
# 55                    Inputs: Fertilizers by Nutrient  2019-08-22
# 56                                   Inputs: Land Use  2019-12-03
# 57                              Investment: Machinery  2018-01-16
# 58                             Inputs: Pesticides Use  2019-09-02
# 59                           Inputs: Pesticides Trade  2019-06-27
# 60                      Investment: Machinery Archive  2018-01-16
# 61                                Trade: Live animals  2019-10-09
# 62                               Trade: Trade Indices  2019-10-09
# 63                Trade: Crops and livestock products  2019-10-09
#
#                                                 Email  \
# 0                                      asti@cgiar.org
# 1                                      asti@cgiar.org
# 2                                     faostat@fao.org
# 3                                     faostat@fao.org
# 4                                     faostat@fao.org
# 5   Mukesh.Srivastava@fao.org; Investment-Data@fao...
# 6                                     faostat@fao.org
# 7                                  macrostats@fao.org
# 8                                     faostat@fao.org
# 9                                     faostat@fao.org
# 10                                    faostat@fao.org
# 11                                    faostat@fao.org
# 12                                    faostat@fao.org
# 13                                    faostat@fao.org
# 14                                    faostat@fao.org
# 15                                    faostat@fao.org
# 16                                    faostat@fao.org
# 17                           Investment-data@fao.org;
# 18                                    faostat@fao.org
# 19                   Food-Security-Statistics@FAO.org
# 20                                    faostat@fao.org
# 21                                    faostat@fao.org
# 22                                    faostat@fao.org
# 23                                    faostat@fao.org
# 24                                    faostat@fao.org
# 25                                    faostat@fao.org
# 26                                    faostat@fao.org
# 27                                    faostat@fao.org
# 28                                    faostat@fao.org
# 29                                    faostat@fao.org
# ..                                                ...
# 34                                    faostat@fao.org
# 35                                    faostat@fao.org
# 36                                    faostat@fao.org
# 37                                    faostat@fao.org
# 38    Piero.Conforti@fao.org; Investment-Data@fao.org
# 39                                    faostat@fao.org
# 40                             Piero.Conforti@fao.org
# 41                             Piero.Conforti@fao.org
# 42                                 macrostats@fao.org
# 43                                    faostat@fao.org
# 44                                    faostat@fao.org
# 45                                    faostat@fao.org
# 46                                    faostat@fao.org
# 47                                    faostat@fao.org
# 48                                    faostat@fao.org
# 49                                    faostat@fao.org
# 50                                    faostat@fao.org
# 51                                    faostat@fao.org
# 52                                    faostat@fao.org
# 53                                    faostat@fao.org
# 54                                    faostat@fao.org
# 55                                    faostat@fao.org
# 56                                    faostat@fao.org
# 57                                    faostat@fao.org
# 58                                    faostat@fao.org
# 59                                    faostat@fao.org
# 60                                               None
# 61                                    faostat@fao.org
# 62                                    faostat@fao.org
# 63                                    faostat@fao.org
#
#                                          FileLocation  \
# 0   http://fenixservices.fao.org/faostat/static/bu...
# 1   http://fenixservices.fao.org/faostat/static/bu...
# 2   http://fenixservices.fao.org/faostat/static/bu...
# 3   http://fenixservices.fao.org/faostat/static/bu...
# 4   http://fenixservices.fao.org/faostat/static/bu...
# 5   http://fenixservices.fao.org/faostat/static/bu...
# 6   http://fenixservices.fao.org/faostat/static/bu...
# 7   http://fenixservices.fao.org/faostat/static/bu...
# 8   http://fenixservices.fao.org/faostat/static/bu...
# 9   http://fenixservices.fao.org/faostat/static/bu...
# 10  http://fenixservices.fao.org/faostat/static/bu...
# 11  http://fenixservices.fao.org/faostat/static/bu...
# 12  http://fenixservices.fao.org/faostat/static/bu...
# 13  http://fenixservices.fao.org/faostat/static/bu...
# 14  http://fenixservices.fao.org/faostat/static/bu...
# 15  http://fenixservices.fao.org/faostat/static/bu...
# 16  http://fenixservices.fao.org/faostat/static/bu...
# 17  http://fenixservices.fao.org/faostat/static/bu...
# 18  http://fenixservices.fao.org/faostat/static/bu...
# 19  http://fenixservices.fao.org/faostat/static/bu...
# 20  http://fenixservices.fao.org/faostat/static/bu...
# 21  http://fenixservices.fao.org/faostat/static/bu...
# 22  http://fenixservices.fao.org/faostat/static/bu...
# 23  http://fenixservices.fao.org/faostat/static/bu...
# 24  http://fenixservices.fao.org/faostat/static/bu...
# 25  http://fenixservices.fao.org/faostat/static/bu...
# 26  http://fenixservices.fao.org/faostat/static/bu...
# 27  http://fenixservices.fao.org/faostat/static/bu...
# 28  http://fenixservices.fao.org/faostat/static/bu...
# 29  http://fenixservices.fao.org/faostat/static/bu...
# ..                                                ...
# 34  http://fenixservices.fao.org/faostat/static/bu...
# 35  http://fenixservices.fao.org/faostat/static/bu...
# 36  http://fenixservices.fao.org/faostat/static/bu...
# 37  http://fenixservices.fao.org/faostat/static/bu...
# 38  http://fenixservices.fao.org/faostat/static/bu...
# 39  http://fenixservices.fao.org/faostat/static/bu...
# 40  http://fenixservices.fao.org/faostat/static/bu...
# 41  http://fenixservices.fao.org/faostat/static/bu...
# 42  http://fenixservices.fao.org/faostat/static/bu...
# 43  http://fenixservices.fao.org/faostat/static/bu...
# 44  http://fenixservices.fao.org/faostat/static/bu...
# 45  http://fenixservices.fao.org/faostat/static/bu...
# 46  http://fenixservices.fao.org/faostat/static/bu...
# 47  http://fenixservices.fao.org/faostat/static/bu...
# 48  http://fenixservices.fao.org/faostat/static/bu...
# 49  http://fenixservices.fao.org/faostat/static/bu...
# 50  http://fenixservices.fao.org/faostat/static/bu...
# 51  http://fenixservices.fao.org/faostat/static/bu...
# 52  http://fenixservices.fao.org/faostat/static/bu...
# 53  http://fenixservices.fao.org/faostat/static/bu...
# 54  http://fenixservices.fao.org/faostat/static/bu...
# 55  http://fenixservices.fao.org/faostat/static/bu...
# 56  http://fenixservices.fao.org/faostat/static/bu...
# 57  http://fenixservices.fao.org/faostat/static/bu...
# 58  http://fenixservices.fao.org/faostat/static/bu...
# 59  http://fenixservices.fao.org/faostat/static/bu...
# 60  http://fenixservices.fao.org/faostat/static/bu...
# 61  http://fenixservices.fao.org/faostat/static/bu...
# 62  http://fenixservices.fao.org/faostat/static/bu...
# 63  http://fenixservices.fao.org/faostat/static/bu...
#
#                                              FileName  FileRows FileSize  \
# 0       ASTI_Expenditures_E_All_Data_(Normalized).zip      3094     26KB
# 1        ASTI_Researchers_E_All_Data_(Normalized).zip      3154     25KB
# 2   CommodityBalances_Crops_E_All_Data_(Normalized...   7695363  46296KB
# 3   CommodityBalances_LivestockFish_E_All_Data_(No...   2868088  16605KB
# 4        FoodSupply_Crops_E_All_Data_(Normalized).zip   4903939  32418KB
# 5   Investment_CountryInvestmentStatisticsProfile_...     66029    546KB
# 6   FoodSupply_LivestockFish_E_All_Data_(Normalize...   2156342  14340KB
# 7   Investment_CapitalStock_E_All_Data_(Normalized...     72838    582KB
# 8   Environment_Fertilizers_E_All_Data_(Normalized...      9023     63KB
# 9   Environment_Emissions_intensities_E_All_Data_(...    383574   3078KB
# 10  Environment_LivestockPatterns_E_All_Data_(Norm...    440552   2894KB
# 11    Environment_LandUse_E_All_Data_(Normalized).zip    148718    962KB
# 12  Environment_Emissions_by_Sector_E_All_Data_(No...    796209   6300KB
# 13  Environment_LivestockManure_E_All_Data_(Normal...   2401658  22722KB
# 14  Environment_Pesticides_E_All_Data_(Normalized)...      5209     31KB
# 15      FoodBalanceSheets_E_All_Data_(Normalized).zip   1219867   7099KB
# 16  FoodBalanceSheetsHistoric_E_All_Data_(Normaliz...  11486892  67671KB
# 17  Investment_ForeignDirectInvestment_E_All_Data_...     34082    291KB
# 18               Forestry_E_All_Data_(Normalized).zip   1992989  13737KB
# 19     Food_Security_Data_E_All_Data_(Normalized).zip     81057    706KB
# 20  Emissions_Agriculture_Crop_Residues_E_All_Data...    746020   6199KB
# 21  Emissions_Agriculture_Burning_crop_residues_E_...    353284   2710KB
# 22  Emissions_Land_Use_Cropland_E_All_Data_(Normal...     18234    113KB
# 23  Emissions_Agriculture_Enteric_Fermentation_E_A...    624166   4635KB
# 24  Emissions_Land_Use_Forest_Land_E_All_Data_(Nor...     78815    478KB
# 25  Emissions_Land_Use_Grassland_E_All_Data_(Norma...     18034    109KB
# 26  Emissions_Agriculture_Burning_Savanna_E_All_Da...    485898   3318KB
# 27  Emissions_Land_Use_Burning_Biomass_E_All_Data_...    223839   1572KB
# 28  Emissions_Land_Use_Land_Use_Total_E_All_Data_(...     87311    498KB
# 29  Emissions_Agriculture_Manure_Management_E_All_...   2981723  21855KB
# ..                                                ...       ...      ...
# 34  Emissions_Agriculture_Manure_applied_to_soils_...   2606654  21657KB
# 35  Emissions_Agriculture_Cultivated_Organic_Soils...     43122    268KB
# 36  Emissions_Agriculture_Synthetic_Fertilizers_E_...    144660   1185KB
# 37  Investment_CreditAgriculture_E_All_Data_(Norma...     13060    114KB
# 38  Investment_GovernmentExpenditure_E_All_Data_(N...     65795    542KB
# 39  Environment_LandCover_E_All_Data_(Normalized).zip    157374   1155KB
# 40  Macro-Statistics_Key_Indicators_E_All_Data_(No...    722110   7164KB
# 41  Employment_Indicators_E_All_Data_(Normalized).zip     32325    301KB
# 42              Deflators_E_All_Data_(Normalized).zip     76050    651KB
# 43          Exchange_rate_E_All_Data_(Normalized).zip      9972     84KB
# 44          Price_Indices_E_All_Data_(Normalized).zip    297875   2619KB
# 45                 Prices_E_All_Data_(Normalized).zip    452610   3354KB
# 46   Production_Livestock_E_All_Data_(Normalized).zip    173071   1237KB
# 47       Production_Crops_E_All_Data_(Normalized).zip   2493838  18130KB
# 48  Production_CropsProcessed_E_All_Data_(Normaliz...    223351    882KB
# 49     Production_Indices_E_All_Data_(Normalized).zip    592028   4123KB
# 50  Production_LivestockPrimary_E_All_Data_(Normal...   1279695   9032KB
# 51  Production_LivestockProcessed_E_All_Data_(Norm...    102982    749KB
# 52    Value_of_Production_E_All_Data_(Normalized).zip   3898053  36291KB
# 53  Inputs_FertilizersArchive_E_All_Data_(Normaliz...   1167109   5761KB
# 54  Inputs_FertilizersProduct_E_All_Data_(Normaliz...    164468   1386KB
# 55  Inputs_FertilizersNutrient_E_All_Data_(Normali...     36604    281KB
# 56         Inputs_LandUse_E_All_Data_(Normalized).zip    193916   1227KB
# 57   Investment_Machinery_E_All_Data_(Normalized).zip    146926   1245KB
# 58  Inputs_Pesticides_Use_E_All_Data_(Normalized).zip     43585    331KB
# 59  Inputs_Pesticides_Trade_E_All_Data_(Normalized...     87374    753KB
# 60  Investment_MachineryArchive_E_All_Data_(Normal...    328932   1798KB
# 61      Trade_LiveAnimals_E_All_Data_(Normalized).zip    749165   4709KB
# 62          Trade_Indices_E_All_Data_(Normalized).zip      3286     23KB
# 63  Trade_Crops_Livestock_E_All_Data_(Normalized).zip  15386177  95728KB
#
#    FileType                                              Topic
# 0       csv  All government and nonprofit agencies involved...
# 1       csv  All government, higher education, and nonprofi...
# 2       csv  Most crop and livestock products, including pr...
# 3       csv  Most crop and livestock products, including pr...
# 4       csv  Most crop and livestock products, including pr...
# 5       csv                 Agriculture, forestry and fishing.
# 6       csv  Most crop and livestock products, including pr...
# 7       csv  Agriculture, forestry and fishing (ISIC A+B Re...
# 8       csv           Agriculture, Forestry and Other Land Use
# 9       csv  Agriculture, Forestry and Other Land Use, Gree...
# 10      csv       Agriculture, Forestry and Fisheries (ISIC A)
# 11      csv  Land Use categories, Irrigation and other Agri...
# 12      csv              Agriculture, Greenhouse Gas Emissions
# 13      csv  Organic Nitrogen (N) input from livestock manure.
# 14      csv               Agriculture, Forestry and Fisheries.
# 15      csv  Most crop and livestock products, including pr...
# 16      csv  Most crop and livestock products, including pr...
# 17      csv  Total economy, Agriculture, forestry and fishe...
# 18      csv  Forestry and logging, Manufacture of wood and ...
# 19      csv  See attached document which lists sector cover...
# 20      csv  Agriculture, Forestry and Other Land Use, Gree...
# 21      csv  Agriculture, Forestry and Other Land Use, Gree...
# 22      csv  Agriculture, Forestry and Other Land Use, Gree...
# 23      csv  Agriculture, Forestry and Other Land Use, Gree...
# 24      csv  Agriculture, Forestry and Other Land Use, Gree...
# 25      csv  Agriculture, Forestry and Other Land Use, Gree...
# 26      csv  Agriculture, Forestry and Other Land Use, Gree...
# 27      csv  Agriculture, Forestry and Other Land Use, Gree...
# 28      csv  Agriculture, Forestry and Other Land Use, Gree...
# 29      csv               Agriculture Greenhouse Gas Emissions
# ..      ...                                                ...
# 34      csv  Agriculture, Forestry and Other Land Use, Gree...
# 35      csv  Agriculture, Forestry and Other Land Use, Gree...
# 36      csv  Agriculture, Forestry and Other Land Use, Gree...
# 37      csv  Total economy and Agriculture, forestry and fi...
# 38      csv  Besides Total Expenditure, the GEA dataset cov...
# 39      csv                                         Land cover
# 40      csv  *TE - Total Economy (ISIC Rev. 4, A-U_01-99),*...
# 41      csv                                      Labour market
# 42      csv  *TE - Total Economy (ISIC Rev. 3, A-Q_01-99 an...
# 43      csv                                       All sectors.
# 44      csv  Most crop and livestock products under agricul...
# 45      csv  Most crop and livestock products under agricul...
# 46      csv  Most crop and livestock products under agricul...
# 47      csv    Most crop products under agricultural activity.
# 48      csv  Most crop products and processed crops under a...
# 49      csv  Most crop products and processed crops under a...
# 50      csv  Agriculture holdings and enterprises for proce...
# 51      csv  Agriculture holdings and enterprises for proce...
# 52      csv                                               None
# 53      csv       Agriculture, Forestry and Fisheries (ISIC A)
# 54      csv         Environment, Agricultural input statistics
# 55      csv         Environment, Agricultural input statistics
# 56      csv       Agriculture, Forestry and Fisheries (ISIC A)
# 57      csv        Agriculture, excluding forestry and fishing
# 58      csv                               Agriculture (ISIC A)
# 59      csv      Agriculture, Forestry and Fisheries (ISIC A).
# 60      csv                                               None
# 61      csv  The dataset contains all food and agricultural...
# 62      csv  The dataset contains all food and agricultural...
# 63      csv  The dataset contains all food and agricultural...
#
# [64 rows x 13 columns]

# %%
pd.DataFrame(metadata_by_code['QC'])
# Out:
#    domain_code metadata_code metadata_group_code  \
# 0           QC           1.1                   1
# 1           QC           1.2                   1
# 2           QC           1.3                   1
# 3           QC           1.4                   1
# 4           QC           1.5                   1
# 5           QC           1.6                   1
# 6           QC           1.7                   1
# 7           QC           1.8                   1
# 8           QC           2.1                   2
# 9           QC           2.2                   2
# 10          QC           2.3                   2
# 11          QC           3.1                   3
# 12          QC           3.2                   3
# 13          QC         3.2.1                   3
# 14          QC         3.2.2                   3
# 15          QC         3.2.3                   3
# 16          QC           3.3                   3
# 17          QC           3.4                   3
# 18          QC           3.5                   3
# 19          QC           3.6                   3
# 20          QC           3.7                   3
# 21          QC         3.7.1                   3
# 22          QC         3.7.2                   3
# 23          QC           3.8                   3
# 24          QC         3.8.1                   3
# 25          QC         3.8.2                   3
# 26          QC         3.8.3                   3
# 27          QC           3.9                   3
# 28          QC         3.9.1                   3
# 29          QC           4.0                   4
# ..         ...           ...                 ...
# 57          QC          13.1                  13
# 58          QC          13.2                  13
# 59          QC          13.3                  13
# 60          QC          14.1                  14
# 61          QC          14.2                  14
# 62          QC          14.3                  14
# 63          QC          15.1                  15
# 64          QC          15.2                  15
# 65          QC          16.1                  16
# 66          QC        16.1.1                  16
# 67          QC          16.2                  16
# 68          QC        16.2.1                  16
# 69          QC          17.1                  17
# 70          QC        17.1.1                  17
# 71          QC          17.2                  17
# 72          QC          18.0                  18
# 73          QC          19.1                  19
# 74          QC          19.2                  19
# 75          QC          20.1                  20
# 76          QC        20.1.1                  20
# 77          QC        20.1.2                  20
# 78          QC          20.2                  20
# 79          QC          20.3                  20
# 80          QC          20.4                  20
# 81          QC          20.5                  20
# 82          QC        20.5.1                  20
# 83          QC        20.5.2                  20
# 84          QC        20.5.3                  20
# 85          QC          20.6                  20
# 86          QC          21.0                  21
#
#                           metadata_group_label  \
# 0                                     Contacts
# 1                                     Contacts
# 2                                     Contacts
# 3                                     Contacts
# 4                                     Contacts
# 5                                     Contacts
# 6                                     Contacts
# 7                                     Contacts
# 8                                  Action Date
# 9                                  Action Date
# 10                                 Action Date
# 11                   Main Characteristics data
# 12                   Main Characteristics data
# 13                   Main Characteristics data
# 14                   Main Characteristics data
# 15                   Main Characteristics data
# 16                   Main Characteristics data
# 17                   Main Characteristics data
# 18                   Main Characteristics data
# 19                   Main Characteristics data
# 20                   Main Characteristics data
# 21                   Main Characteristics data
# 22                   Main Characteristics data
# 23                   Main Characteristics data
# 24                   Main Characteristics data
# 25                   Main Characteristics data
# 26                   Main Characteristics data
# 27                   Main Characteristics data
# 28                   Main Characteristics data
# 29                                       Units
# ..                                         ...
# 57                        Classification Users
# 58                        Classification Users
# 59                        Classification Users
# 60                       Main Sources of Error
# 61                       Main Sources of Error
# 62                       Main Sources of Error
# 63                  Timeliness and punctuality
# 64                  Timeliness and punctuality
# 65  Comparability Between Countries or Regions
# 66  Comparability Between Countries or Regions
# 67  Comparability Between Countries or Regions
# 68  Comparability Between Countries or Regions
# 69      Differences of the statistical outputs
# 70      Differences of the statistical outputs
# 71      Differences of the statistical outputs
# 72                             Cost associated
# 73                     General revision policy
# 74                     General revision policy
# 75                         Identification Data
# 76                         Identification Data
# 77                         Identification Data
# 78                         Identification Data
# 79                         Identification Data
# 80                         Identification Data
# 81                         Identification Data
# 82                         Identification Data
# 83                         Identification Data
# 84                         Identification Data
# 85                         Identification Data
# 86                                     Comment
#
#                                 metadata_label  \
# 0                         Contact organisation
# 1                    Contact organisation unit
# 2                                 Contact name
# 3                      Contact person function
# 4                         Contact mail address
# 5                        Contact email address
# 6                         Contact phone number
# 7                           Contact fax number
# 8                      Metadata last certified
# 9                         Metadata last posted
# 10                        Metadata last update
# 11                            Data description
# 12                       Classification system
# 13                      Primary classification
# 14                    Secondary classification
# 15                    Secondary classification
# 16                             Sector coverage
# 17        Statistical concepts and definitions
# 18                            Statistical unit
# 19                      Statistical population
# 20                              Reference area
# 21                       Code - reference area
# 22    Code - Number of countries/areas covered
# 23                               Time coverage
# 24                                 Periodicity
# 25                                Start period
# 26                                  End period
# 27                                 Base period
# 28                            Base period code
# 29                             Unit of Measure
# ..                                         ...
# 57                                  User needs
# 58                           User satisfaction
# 59                                Completeness
# 60                            Overall accuracy
# 61                              Sampling error
# 62                          Non-sampling error
# 63                                  Timeliness
# 64                                 Punctuality
# 65                Comparability - geographical
# 66           Code - geographical comparability
# 67                   Comparability - over time
# 68                   Code - time Comparability
# 69                    Coherence - cross domain
# 70               Code - cross domain coherence
# 71                        Coherence - internal
# 72                             Cost and Burden
# 73                      Data revision - policy
# 74                    Data revision - practice
# 75                                 Source data
# 76  Code - Origin fro predominate  source data
# 77                         Code - type of data
# 78                Frequency of data collection
# 79  Code - Type and purpose of data collection
# 80                             Data validation
# 81                            Data compilation
# 82                 Code for type of processing
# 83       Imputation rate (frequency and value)
# 84                               Coverage rate
# 85                                  Adjustment
# 86                                     Comment
#
#                                         metadata_text   ord
# 0   Food and Agriculture Organization of the Unite...   110
# 1                           Statistics Division (ESS)   120
# 2                                    Mr. Salar Tayyib   130
# 3                     Team Leader/Senior Statistician   140
# 4                                                       150
# 5                                     faostat@fao.org   160
# 6                                                       170
# 7                                                       180
# 8                                           Nov. 2016   210
# 9                                           Nov. 2016   220
# 10                                          Nov. 2016   230
# 11  Crop statistics are recorded for 173 products,...   310
# 12  CPC 2.1 Expanded and FAO Commodity List (FCL),...   320
# 13                                                NaN   321
# 14                                                NaN   322
# 15                                                NaN   323
# 16    Most crop products under agricultural activity.   330
# 17  Areas refer to the area under cultivation. Are...   340
# 18  Agriculture holdings cultivated for the produc...   350
# 19      All areas cultivated with crops in a country.   360
# 20  All countries of the world and geographical ag...   370
# 21                                                NaN   371
# 22                                                NaN   372
# 23                  1961 – 2014 (up to 2013 for Seed)   380
# 24                                             Annual   381
# 25                                                NaN   382
# 26                                                NaN   383
# 27                                    Not applicable.   390
# 28                                                NaN   391
# 29  Production Quantity and Seed: tonnes; Area har...   401
# ..                                                ...   ...
# 57  The main users are FAO analysts, other interna...  1310
# 58  The FAOSTAT User Consultation took place durin...  1320
# 59  The coverage of official production data provi...  1330
# 60  It is not possible to assess the overall accur...  1410
# 61  No information is available regarding sampling...  1420
# 62  No information is available regarding the magn...  1430
# 63  Data are uploaded for dissemination twice a ye...  1510
# 64                                                     1520
# 65  There is limited geographical comparability du...  1610
# 66                                                NaN  1611
# 67  For shorter time periods, reasonably good comp...  1620
# 68                                                NaN  1621
# 69  Common product classifications help to ensure ...  1710
# 70                                                NaN  1711
# 71  It is expected that the internal coherence has...  1720
# 72                                                NaN  1801
# 73  Prefilled questionnaires are sent out with rep...  1910
# 74  The revised data for n-1 and n-2 are dissemina...  1920
# 75  The main data source is official statistics fr...  2010
# 76                                                NaN  2011
# 77                                                NaN  2012
# 78                       Data are collected annually.  2020
# 79                                                     2030
# 80  Countries are responsible for transmitting dat...  2040
# 81  Data are uploaded for dissemination twice a ye...  2050
# 82                                                NaN  2051
# 83  Years: 2006-2015    IR (%) IF (%)   Production...  2052
# 84  FAO strives to provide data for all countries ...  2053
# 85                           No adjustments are made.  2060
# 86                                                NaN  2101
#
# [87 rows x 7 columns]

# %% [markdown]
# ## Check whether we have all datasets

# %%
files_we_have = set(map(get_name_from_path, glob(os.path.join(DATA_PATH, "*.zip"))))
files_in_metadata = set(map(lambda d: d['FileName'], datasets))

# %%
files_in_metadata - files_we_have
# Out:
# set()

# %% [markdown]
# ## Metadata extraction utilities

# %%
def find(fn, lst):
    for item in lst:
        if fn(item):
            return item

def get_metadata_field(code, label):
    try:
        return find(
            lambda row: row['metadata_label'] == label, 
            metadata_by_code[code]
        )['metadata_text']
    except:
        return ""

# %% [markdown]
# ## **Extract datasets** & **sources**

# %%
pd.DataFrame(datasets).head()
# Out:
#   CompressionFormat                             Contact DatasetCode  \
# 0               zip  Nienke Beintema and Gert-Jan Stads          AE
# 1               zip  Nienke Beintema and Gert-Jan Stads          AF
# 2               zip                    Mr. Salar Tayyib          BC
# 3               zip                    Mr. Salar Tayyib          BL
# 4               zip                    Mr. Salar Tayyib          CC
#
#                                   DatasetDescription  \
# 0  ASTI collects primary time-series data on agri...
# 1  ASTI collects primary time-series data on agri...
# 2  Commodity balances show balances of food and a...
# 3  Food supply data is some of the most important...
# 4  Food supply data is some of the most important...
#
#                                          DatasetName  DateUpdate  \
# 0             ASTI R&D Indicators: ASTI-Expenditures  2019-11-11
# 1              ASTI R&D Indicators: ASTI-Researchers  2019-11-11
# 2  Food Balance: Commodity Balances - Crops Prima...  2018-01-16
# 3  Food Balance: Commodity Balances - Livestock a...  2018-01-17
# 4  Food Balance: Food Supply - Crops Primary Equi...  2018-02-05
#
#              Email                                       FileLocation  \
# 0   asti@cgiar.org  http://fenixservices.fao.org/faostat/static/bu...
# 1   asti@cgiar.org  http://fenixservices.fao.org/faostat/static/bu...
# 2  faostat@fao.org  http://fenixservices.fao.org/faostat/static/bu...
# 3  faostat@fao.org  http://fenixservices.fao.org/faostat/static/bu...
# 4  faostat@fao.org  http://fenixservices.fao.org/faostat/static/bu...
#
#                                             FileName  FileRows FileSize  \
# 0      ASTI_Expenditures_E_All_Data_(Normalized).zip      3094     26KB
# 1       ASTI_Researchers_E_All_Data_(Normalized).zip      3154     25KB
# 2  CommodityBalances_Crops_E_All_Data_(Normalized...   7695363  46296KB
# 3  CommodityBalances_LivestockFish_E_All_Data_(No...   2868088  16605KB
# 4       FoodSupply_Crops_E_All_Data_(Normalized).zip   4903939  32418KB
#
#   FileType                                              Topic
# 0      csv  All government and nonprofit agencies involved...
# 1      csv  All government, higher education, and nonprofi...
# 2      csv  Most crop and livestock products, including pr...
# 3      csv  Most crop and livestock products, including pr...
# 4      csv  Most crop and livestock products, including pr...

# %%
owid_datasets = [] # pd.DataFrame(columns=['id', 'name', 'code', 'zip_file'])
owid_sources = [] # pd.DataFrame(columns=['id', 'name', 'description', 'dataset_id'])

for dataset in datasets:
    
    # DATASET
    
    name = dataset['DatasetName']
    code = dataset['DatasetCode']
    
    owid_datasets.append({
        'id': code, 
        'code': code,
        'name': name,
        'description': dataset['DatasetDescription'],
        'zip_filename': dataset['FileName']
    })
    
    # SOURCE
    
    source_desc = {}
    source_desc['dataPublishedBy'] = "Food and Agriculture Organization of the United Nations (FAO) (2019)"
    source_desc['dataPublisherSource'] = get_metadata_field(code, 'Source data')
    source_desc['link'] = "http://www.fao.org/faostat/en/?#data/"
    source_desc['retrievedDate'] = datetime.datetime.now().strftime("%d-%b-%Y")
    source_desc['additionalInfo'] = get_metadata_field(code, 'Statistical concepts and definitions')
    
    owid_sources.append({
        'id': code,
        'dataset_id': code,
        'name': name,
        'description': json.dumps(source_desc)
    })

# %%
pd.DataFrame(owid_datasets)[['id', 'name', 'description']].to_csv(
    os.path.join(OUTPUT_PATH, 'datasets.csv'),
    index=False
)

# %%
pd.DataFrame(owid_sources)[['id', 'name', 'description', 'dataset_id']].to_csv(
    os.path.join(OUTPUT_PATH, 'sources.csv'),
    index=False
)

# %% [markdown]
# ## **Extract variables** & **datapoints** to CSVs

# %% [markdown]
# The unique sets of headers extracted from the **used datasets only**, without the excluded.

# %% [markdown]
# ### File loading utilities

# %%
def load_dataset(code):
    dataset = find(lambda d: d['code'] == code, owid_datasets)
    zip_filepath = os.path.join(DATA_PATH, dataset['zip_filename'])
    csv_filepath = unzip_csv(zip_filepath)
    df = pd.read_csv(csv_filepath, encoding='latin-1', low_memory=False)
    os.remove(csv_filepath)
    return df

def unzip_csv(zip_filepath):
    """Returns the path of the unzipped CSV"""
    zip_ref = zipfile.ZipFile(zip_filepath, 'r')
    
    # Some ZIP files contain multiple files, usually one is a codebook for Flags
    # used in the dataset. We only want the CSVs that have 'All_Data' in their
    # filename.
    csv_filename = find(lambda name: 'All_Data' in name, zip_ref.namelist())
    
    zip_ref.extract(csv_filename, DATA_UNZIP_PATH)
    zip_ref.close()
    
    csv_filepath = os.path.join(DATA_UNZIP_PATH, csv_filename)
    
    return csv_filepath

# %% [markdown]
# #### Extract the column types for each dataset (for diagnostic purposes)

# %%
# all_dataset_columns = pd.DataFrame({
#     'code': [d['code'] for d in owid_datasets],
#     'columns': [list(load_dataset(d['code']).columns) for d in owid_datasets]
# })

# %%
# all_dataset_columns.merge(pd.DataFrame(owid_datasets), on='code')
# Out:
#     code                                            columns  \
# 0     AE  [Area Code, Area, Item Code, Item, Element Cod...
# 1     AF  [Area Code, Area, Item Code, Item, Element Cod...
# 2     BC  [Area Code, Area, Item Code, Item, Element Cod...
# 3     BL  [Area Code, Area, Item Code, Item, Element Cod...
# 4     CC  [Area Code, Area, Item Code, Item, Element Cod...
# 5   CISP  [Area Code, Area, Item Code, Item, Element Cod...
# 6     CL  [Area Code, Area, Item Code, Item, Element Cod...
# 7     CS  [Area Code, Area, Item Code, Item, Element Cod...
# 8     EF  [Area Code, Area, Item Code, Item, Element Cod...
# 9     EI  [Area Code, Area, Item Code, Item, Element Cod...
# 10    EK  [Area Code, Area, Item Code, Item, Element Cod...
# 11    EL  [Area Code, Area, Item Code, Item, Element Cod...
# 12    EM  [Area Code, Area, Item Code, Item, Element Cod...
# 13   EMN  [Area Code, Area, Item Code, Item, Element Cod...
# 14    EP  [Area Code, Area, Item Code, Item, Element Cod...
# 15   FBS  [Area Code, Area, Item Code, Item, Element Cod...
# 16  FBSH  [Area Code, Area, Item Code, Item, Element Cod...
# 17   FDI  [Area Code, Area, Item Code, Item, Element Cod...
# 18    FO  [Area Code, Area, Item Code, Item, Element Cod...
# 19    FS  [Area Code, Area, Item Code, Item, Element Cod...
# 20    GA  [Area Code, Area, Item Code, Item, Element Cod...
# 21    GB  [Area Code, Area, Item Code, Item, Element Cod...
# 22    GC  [Area Code, Area, Item Code, Item, Element Cod...
# 23    GE  [Area Code, Area, Item Code, Item, Element Cod...
# 24    GF  [Area Code, Area, Item Code, Item, Element Cod...
# 25    GG  [Area Code, Area, Item Code, Item, Element Cod...
# 26    GH  [Area Code, Area, Item Code, Item, Element Cod...
# 27    GI  [Area Code, Area, Item Code, Item, Element Cod...
# 28    GL  [Area Code, Area, Item Code, Item, Element Cod...
# 29    GM  [Area Code, Area, Item Code, Item, Element Cod...
# ..   ...                                                ...
# 34    GU  [Area Code, Area, Item Code, Item, Element Cod...
# 35    GV  [Area Code, Area, Item Code, Item, Element Cod...
# 36    GY  [Area Code, Area, Item Code, Item, Element Cod...
# 37    IC  [Area Code, Area, Item Code, Item, Element Cod...
# 38    IG  [Area Code, Area, Item Code, Item, Element Cod...
# 39    LC  [Area Code, Area, Item Code, Item, Element Cod...
# 40    MK  [Area Code, Area, Item Code, Item, Element Cod...
# 41    OE  [Area Code, Area, Source Code, FAO Source, Ind...
# 42    PD  [Area Code, Area, Item Code, Item, Element Cod...
# 43    PE  [Area Code, Area, Item Code, Item, ISO Currenc...
# 44    PI  [Area Code, Area, Item Code, Item, Element Cod...
# 45    PP  [Area Code, Area, Item Code, Item, Element Cod...
# 46    QA  [Area Code, Area, Item Code, Item, Element Cod...
# 47    QC  [Area Code, Area, Item Code, Item, Element Cod...
# 48    QD  [Area Code, Area, Item Code, Item, Element Cod...
# 49    QI  [Area Code, Area, Item Code, Item, Element Cod...
# 50    QL  [Area Code, Area, Item Code, Item, Element Cod...
# 51    QP  [Area Code, Area, Item Code, Item, Element Cod...
# 52    QV  [Area Code, Area, Item Code, Item, Element Cod...
# 53    RA  [Area Code, Area, Item Code, Item, Element Cod...
# 54   RFB  [Area Code, Area, Item Code, Item, Element Cod...
# 55   RFN  [Area Code, Area, Item Code, Item, Element Cod...
# 56    RL  [Area Code, Area, Item Code, Item, Element Cod...
# 57    RM  [Area Code, Area, Item Code, Item, Element Cod...
# 58    RP  [Area Code, Area, Item Code, Item, Element Cod...
# 59    RT  [Area Code, Area, Item Code, Item, Element Cod...
# 60    RY  [Area Code, Area, Item Code, Item, Element Cod...
# 61    TA  [Area Code, Area, Item Code, Item, Element Cod...
# 62    TI  [Area Code, Area, Item Code, Item, Element Cod...
# 63    TP  [Area Code, Area, Item Code, Item, Element Cod...
#
#                                           description    id  \
# 0   ASTI collects primary time-series data on agri...    AE
# 1   ASTI collects primary time-series data on agri...    AF
# 2   Commodity balances show balances of food and a...    BC
# 3   Food supply data is some of the most important...    BL
# 4   Food supply data is some of the most important...    CC
# 5   The Country Investment Statistics Profile doma...  CISP
# 6   Food supply data is some of the most important...    CL
# 7   As part of the FAO Agriculture Capital Stock (...    CS
# 8   The data describe the use of chemical and mine...    EF
# 9   Intensities of greenhouse gas (GHG) emissions ...    EI
# 10  The Livestock Patterns domain of the FAOSTAT A...    EK
# 11  The Agri-environmental IndicatorsLand Use dom...    EL
# 12  The FAOSTAT Emissions shares domain of FAOSTAT...    EM
# 13  The Livestock Manure domain under the FAOSTAT ...   EMN
# 14  Agri-environmental indicator on the Use of pes...    EP
# 15  Food Balance Sheet presents a comprehensive pi...   FBS
# 16  Food Balance Sheet presents a comprehensive pi...  FBSH
# 17  All data originates from the United Nations Co...   FDI
# 18  The database contains data on the production a...    FO
# 19  For detailed description of the indicators bel...    FS
# 20  Greenhouse gas (GHG) emissions from crop resid...    GA
# 21  Greenhouse Gas (GHG) emissions from burning cr...    GB
# 22  Greenhouse gas (GHG) emissions in the domain "...    GC
# 23  Greenhouse gas (GHG) emissions from enteric fe...    GE
# 24  Annual net CO2 emission/removal from Forest La...    GF
# 25  Greenhouse gas (GHG) emissions in the domain "...    GG
# 26  Greenhouse Gas (GHG) emissions from burning of...    GH
# 27  Greenhouse Gas (GHG) emissions from burning of...    GI
# 28  Land Use Total contains all GHG emissions and ...    GL
# 29  Greenhouse gas (GHG) emissions from manure man...    GM
# ..                                                ...   ...
# 34  GHG emissions from manure applied to soils con...    GU
# 35  The domain Cultivation of Organic soils contai...    GV
# 36  Greenhouse gas (GHG) emissions from synthetic ...    GY
# 37  The Credit to Agriculture dataset provides nat...    IC
# 38  The Statistics Division of FAO collects annual...    IG
# 39  The FAOSTAT domain Land Cover under the Agri-E...    LC
# 40  TheFAOSTAT Macro Indicatorsdatabase provides a...    MK
# 41  The FAOSTAT Employment indicators module conta...    OE
# 42  The FAOSTAT Deflators database provides the fo...    PD
# 43  Annual exchange rates, national currency units...    PE
# 44  Indices of agricultural producer prices that m...    PI
# 45  This sub-domain contains data on Agriculture P...    PP
# 46  The dataset contains the following commodities...    QA
# 47  Crop statistics are recorded for 173 products,...    QC
# 48  The dataset covers the following commodities: ...    QD
# 49  The dataset includes data on gross and net pro...    QI
# 50  The dataset contains the following commodities...    QL
# 51  The dataset covers the following commodities: ...    QP
# 52  The data set includes data on gross and net pr...    QV
# 53  The Fertilizer archive dataset containsinforma...    RA
# 54  The Fertilizers by Product dataset contains in...   RFB
# 55  The Fertilizers by Nutrient dataset contains i...   RFN
# 56  The FAOSTAT Land Use domain contains data on f...    RL
# 57  Important notice: FAOSTAT database on Agricult...    RM
# 58  The Pesticides Use database includes data on t...    RP
# 59  This domain contains data on pesticides and co...    RT
# 60                                               None    RY
# 61  The food and agricultural trade dataset is col...    TA
# 62  The food and agricultural trade dataset is col...    TI
# 63  The food and agricultural trade dataset is col...    TP
#
#                                                  name  \
# 0              ASTI R&D Indicators: ASTI-Expenditures
# 1               ASTI R&D Indicators: ASTI-Researchers
# 2   Food Balance: Commodity Balances - Crops Prima...
# 3   Food Balance: Commodity Balances - Livestock a...
# 4   Food Balance: Food Supply - Crops Primary Equi...
# 5   Investment: Country Investment Statistics Profile
# 6   Food Balance: Food Supply - Livestock and Fish...
# 7                     Macro-Statistics: Capital Stock
# 8   Agri-Environmental Indicators: Fertilizers ind...
# 9   Agri-Environmental Indicators: Emissions inten...
# 10  Agri-Environmental Indicators: Livestock Patterns
# 11  Agri-Environmental Indicators: Land use indica...
# 12    Agri-Environmental Indicators: Emissions shares
# 13    Agri-Environmental Indicators: Livestock Manure
# 14  Agri-Environmental Indicators: Pesticides indi...
# 15                    Food Balance: New Food Balances
# 16  Food Balance: Food Balances (old methodology a...
# 17        Investment: Foreign Direct Investment (FDI)
# 18            Forestry: Forestry Production and Trade
# 19   Food Security: Suite of Food Security Indicators
# 20             Emissions - Agriculture: Crop Residues
# 21   Emissions - Agriculture: Burning - Crop Residues
# 22                     Emissions - Land Use: Cropland
# 23      Emissions - Agriculture: Enteric Fermentation
# 24                  Emissions - Land Use: Forest Land
# 25                    Emissions - Land Use: Grassland
# 26         Emissions - Agriculture: Burning - Savanna
# 27            Emissions - Land Use: Burning - Biomass
# 28               Emissions - Land Use: Land Use Total
# 29         Emissions - Agriculture: Manure Management
# ..                                                ...
# 34   Emissions - Agriculture: Manure applied to Soils
# 35  Emissions - Agriculture: Cultivation of Organi...
# 36     Emissions - Agriculture: Synthetic Fertilizers
# 37                  Investment: Credit to Agriculture
# 38                 Investment: Government Expenditure
# 39          Agri-Environmental Indicators: Land Cover
# 40                 Macro-Statistics: Macro Indicators
# 41                      Inputs: Employment Indicators
# 42                                  Prices: Deflators
# 43                    Prices: Exchange rates - Annual
# 44            Prices: Producer Price Indices - Annual
# 45                   Prices: Producer Prices - Annual
# 46                           Production: Live Animals
# 47                                  Production: Crops
# 48                        Production: Crops processed
# 49                     Production: Production Indices
# 50                      Production: Livestock Primary
# 51                    Production: Livestock Processed
# 52       Production: Value of Agricultural Production
# 53                        Inputs: Fertilizers archive
# 54                     Inputs: Fertilizers by Product
# 55                    Inputs: Fertilizers by Nutrient
# 56                                   Inputs: Land Use
# 57                              Investment: Machinery
# 58                             Inputs: Pesticides Use
# 59                           Inputs: Pesticides Trade
# 60                      Investment: Machinery Archive
# 61                                Trade: Live animals
# 62                               Trade: Trade Indices
# 63                Trade: Crops and livestock products
#
#                                          zip_filename
# 0       ASTI_Expenditures_E_All_Data_(Normalized).zip
# 1        ASTI_Researchers_E_All_Data_(Normalized).zip
# 2   CommodityBalances_Crops_E_All_Data_(Normalized...
# 3   CommodityBalances_LivestockFish_E_All_Data_(No...
# 4        FoodSupply_Crops_E_All_Data_(Normalized).zip
# 5   Investment_CountryInvestmentStatisticsProfile_...
# 6   FoodSupply_LivestockFish_E_All_Data_(Normalize...
# 7   Investment_CapitalStock_E_All_Data_(Normalized...
# 8   Environment_Fertilizers_E_All_Data_(Normalized...
# 9   Environment_Emissions_intensities_E_All_Data_(...
# 10  Environment_LivestockPatterns_E_All_Data_(Norm...
# 11    Environment_LandUse_E_All_Data_(Normalized).zip
# 12  Environment_Emissions_by_Sector_E_All_Data_(No...
# 13  Environment_LivestockManure_E_All_Data_(Normal...
# 14  Environment_Pesticides_E_All_Data_(Normalized)...
# 15      FoodBalanceSheets_E_All_Data_(Normalized).zip
# 16  FoodBalanceSheetsHistoric_E_All_Data_(Normaliz...
# 17  Investment_ForeignDirectInvestment_E_All_Data_...
# 18               Forestry_E_All_Data_(Normalized).zip
# 19     Food_Security_Data_E_All_Data_(Normalized).zip
# 20  Emissions_Agriculture_Crop_Residues_E_All_Data...
# 21  Emissions_Agriculture_Burning_crop_residues_E_...
# 22  Emissions_Land_Use_Cropland_E_All_Data_(Normal...
# 23  Emissions_Agriculture_Enteric_Fermentation_E_A...
# 24  Emissions_Land_Use_Forest_Land_E_All_Data_(Nor...
# 25  Emissions_Land_Use_Grassland_E_All_Data_(Norma...
# 26  Emissions_Agriculture_Burning_Savanna_E_All_Da...
# 27  Emissions_Land_Use_Burning_Biomass_E_All_Data_...
# 28  Emissions_Land_Use_Land_Use_Total_E_All_Data_(...
# 29  Emissions_Agriculture_Manure_Management_E_All_...
# ..                                                ...
# 34  Emissions_Agriculture_Manure_applied_to_soils_...
# 35  Emissions_Agriculture_Cultivated_Organic_Soils...
# 36  Emissions_Agriculture_Synthetic_Fertilizers_E_...
# 37  Investment_CreditAgriculture_E_All_Data_(Norma...
# 38  Investment_GovernmentExpenditure_E_All_Data_(N...
# 39  Environment_LandCover_E_All_Data_(Normalized).zip
# 40  Macro-Statistics_Key_Indicators_E_All_Data_(No...
# 41  Employment_Indicators_E_All_Data_(Normalized).zip
# 42              Deflators_E_All_Data_(Normalized).zip
# 43          Exchange_rate_E_All_Data_(Normalized).zip
# 44          Price_Indices_E_All_Data_(Normalized).zip
# 45                 Prices_E_All_Data_(Normalized).zip
# 46   Production_Livestock_E_All_Data_(Normalized).zip
# 47       Production_Crops_E_All_Data_(Normalized).zip
# 48  Production_CropsProcessed_E_All_Data_(Normaliz...
# 49     Production_Indices_E_All_Data_(Normalized).zip
# 50  Production_LivestockPrimary_E_All_Data_(Normal...
# 51  Production_LivestockProcessed_E_All_Data_(Norm...
# 52    Value_of_Production_E_All_Data_(Normalized).zip
# 53  Inputs_FertilizersArchive_E_All_Data_(Normaliz...
# 54  Inputs_FertilizersProduct_E_All_Data_(Normaliz...
# 55  Inputs_FertilizersNutrient_E_All_Data_(Normali...
# 56         Inputs_LandUse_E_All_Data_(Normalized).zip
# 57   Investment_Machinery_E_All_Data_(Normalized).zip
# 58  Inputs_Pesticides_Use_E_All_Data_(Normalized).zip
# 59  Inputs_Pesticides_Trade_E_All_Data_(Normalized...
# 60  Investment_MachineryArchive_E_All_Data_(Normal...
# 61      Trade_LiveAnimals_E_All_Data_(Normalized).zip
# 62          Trade_Indices_E_All_Data_(Normalized).zip
# 63  Trade_Crops_Livestock_E_All_Data_(Normalized).zip
#
# [64 rows x 6 columns]

# %% [markdown]
# #### Extract all unique dimension values (for diagnostic purposes)

# %%
# for dataset in owid_datasets:
#     df = load_dataset(dataset['code'])
#     dim_cols = [col for col in df.columns if col not in ['Value', 'Note']]
#     pd.concat(
#         [pd.DataFrame({ col: df[col].unique() }) for col in dim_cols], 
#         axis=1
#     ).to_csv(os.path.join('dimensions', dataset['name'] + '.csv'))

# %% [markdown]
# ### Year conversion utility

# %%
def year_to_int(year):
    if isinstance(year, str) and '-' in year:
        start, end = year.split('-')
        return (int(end) + int(start)) // 2
    else:
        return year

# %%
# pd.Series(['2012-2014', '2013-2015']).map(year_to_int)

# %% [markdown]
# ### Column types parameters

# %%
params_by_cols = {
    tuple(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element', 'Year Code', 'Year', 'Unit', 'Value', 'Flag']): {
        'entity': 'Area',
        'breakdown': ['Item', 'Element', 'Unit'],
        'code': ['Item Code', 'Element Code', 'Unit']
    },
    tuple(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element', 'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note']): {
        'entity': 'Area',
        'breakdown': ['Item', 'Element', 'Unit'],
        'code': ['Item Code', 'Element Code', 'Unit']
    },
    tuple(['Country Code', 'Country', 'Item Code', 'Item', 'Element Code', 'Element', 'Year Code', 'Year', 'Unit', 'Value', 'Flag']): {
        'entity': 'Country',
        'breakdown': ['Item', 'Element', 'Unit'],
        'code': ['Item Code', 'Element Code', 'Unit']
    },
    tuple(['Area Code', 'Area', 'Item Code', 'Item', 'ISO Currency Code', 'Currency', 'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note']): {
        'entity': 'Area',
        'breakdown': ['Item', 'Currency'],
        'code': ['Item Code', 'ISO Currency Code']
    },
    tuple(['Area Code', 'Area', 'Source Code', 'FAO Source', 'Indicator Code', 'Indicator', 'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note']): {
        'entity': 'Area',
        'breakdown': ['Indicator', 'FAO Source', 'Unit'],
        'code': ['Indicator Code', 'Source Code', 'Unit']
    }
}

# %% [markdown]
# #### Old column types (left just for reference)

# %%
# column_types = [
#     # 11 columns
#     tuple(["Area Code", "Area", "Item Code", "Item", "ISO Currency Code", "Currency", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     tuple(["CountryCode", "Country", "ItemCode", "Item", "ElementGroup", "ElementCode", "Element", "Year", "Unit", "Value", "Flag"]),
#     tuple(["Area Code", "Area", "Item Code", "Item", "Element Code", "Element", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     tuple(["Country Code", "Country", "Item Code", "Item", "Element Code", "Element", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     tuple(["Country Code", "Country", "Source Code", "Source", "Indicator Code", "Indicator", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     tuple(["Recipient Country Code", "Recipient Country", "Item Code", "Item", "Donor Country Code", "Donor Country", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     # 13 columns
#     tuple(["Reporter Country Code", "Reporter Countries", "Partner Country Code", "Partner Countries", "Item Code", "Item", "Element Code", "Element", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     # 15 columns
#     tuple(["Donor Code", "Donor", "Recipient Country Code", "Recipient Country", "Item Code", "Item", "Element Code", "Element", "Purpose Code", "Purpose", "Year Code", "Year", "Unit", "Value", "Flag"]),
#     # for Indicators_from_Household_Surveys_E_All_Data_(Normalized)
#     tuple(['Survey Code','Survey','Breakdown Variable Code','Breakdown Variable','Breadown by Sex of the Household Head Code','Breadown by Sex of the Household Head','Indicator Code','Indicator','Measure Code','Measure','Unit','Value','Flag']),
#     tuple(['Area Code', 'Area','Source Code','FAO Source','Indicator Code','Indicator','Year Code','Year','Unit','Value','Flag','Note']),
#     # ConsumerPriceIndices_E_All_Data_(Normalized).zip
#     tuple(['Area Code','Area','Item Code','Item','Months Code','Months','Year Code','Year','Unit','Value','Flag','Note']),
#     # Exchange_rate_E_All_Data_(Normalized).zip
#     tuple(['Area Code','Area','Item Code','Item','ISO Currency Code','Currency','Year Code','Year','Unit','Value','Flag','Note']),
#     # Environment_Temperature_change_E_All_Data_(Normalized).zip
#     tuple(['Area Code','Area','Months Code','Months','Element Code','Element','Year Code','Year','Unit','Value','Flag'])
# ]

# %% [markdown]
# ### Data extraction procedure

# %% [markdown]
# Need to specify:
#
# - Variable name prefix
# - Columns to break down by
# - Columns to use for constructing the `code` value
# - What to use as the entity field
# - That we should break down by `Unit` (all tables have it, it's just good if it's explicit)
#
# What we know:
#
# - Every dataset has a `Year` field (which we might need to transform to a single year from a range)

# %%
def process_dataset(code):
    """Returns the variables inserted"""
    
    idx = 0
    
    dataset = find(lambda d: d['code'] == code, owid_datasets)
    df_dataset = load_dataset(code)
    cols = tuple(df_dataset.columns)
    
    if cols not in params_by_cols:
        print('ERROR: processing dataset %s: could not find %s in the list of column sets' % (code, str(cols)))
        return
    
    params = params_by_cols[cols]
    
    variables = []
    
    for key, df in df_dataset.groupby(params['breakdown']):
        idx += 1
        var_id = dataset['code'] + '-' + str(idx)
        name_prefix = dataset['name'].split(":", 1)[1]
        name_suffix = " - ".join(map(str, df[params['breakdown']].iloc[0].to_list()))
        name = " - ".join([name_prefix, name_suffix]).strip()
        code = " - ".join([dataset['code'], *map(str, df[params['code']].iloc[0].to_list())])
        unit = df.iloc[0].to_dict()['Unit'] if 'Unit' in df.columns else ""
        
        variables.append({
            'id': var_id,
            'name': name,
            'code': code,
            'unit': unit,
            'description': dataset['description'],
            'dataset_id': dataset['id'],
            'source_id': dataset['id'] # not a nice way to do it, but we know that source id == dataset id
        })
        
        datapoints = df.rename(columns={"Value": "value", params['entity']: "entity", "Year": "year"})
        
        # Some years are defined as 3-year ranges, e.g. "2013-2015"
        # We want to convert these to a single year
        datapoints['year'] = datapoints['year'].map(year_to_int)
        
        output_path = os.path.join(OUTPUT_PATH, 'datapoints/%s.csv' % str(var_id))
        datapoints[['entity', 'year', 'value']].to_csv(output_path, index=False)
    
    return variables

# %% [markdown]
# ### Process the data files

# %%
# !mkdir -p $OUTPUT_PATH/datapoints

# %%
print("Extracting datapoints & variables...")

# %%
variables = []

for dataset in tqdm(owid_datasets):
    variables += process_dataset(dataset['code'])

pd.DataFrame(variables)[['id', 'name', 'code', 'unit', 'description', 'dataset_id', 'source_id']] \
    .to_csv(os.path.join(OUTPUT_PATH, 'variables.csv'), index=False)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#   2%|▏         | 1/64 [00:00<00:07,  8.41it/s]
# Extracting datapoints & variables...
#   5%|▍         | 3/64 [00:50<07:44,  7.62s/it]
#   6%|▋         | 4/64 [01:07<10:33, 10.56s/it]
#   8%|▊         | 5/64 [01:44<18:06, 18.42s/it]
#   9%|▉         | 6/64 [01:45<12:40, 13.12s/it]
#  11%|█         | 7/64 [01:59<12:47, 13.47s/it]
#  12%|█▎        | 8/64 [02:00<09:04,  9.73s/it]
#  14%|█▍        | 9/64 [02:00<06:17,  6.87s/it]
#  16%|█▌        | 10/64 [02:03<05:08,  5.70s/it]
#  17%|█▋        | 11/64 [02:06<04:18,  4.87s/it]
#  19%|█▉        | 12/64 [02:07<03:13,  3.72s/it]
#  20%|██        | 13/64 [02:16<04:27,  5.24s/it]
#  22%|██▏       | 14/64 [02:35<07:44,  9.30s/it]
#  25%|██▌       | 16/64 [02:53<07:20,  9.18s/it]
#  27%|██▋       | 17/64 [04:29<27:41, 35.34s/it]
#  28%|██▊       | 18/64 [04:29<19:04, 24.88s/it]
#  30%|██▉       | 19/64 [04:45<16:37, 22.17s/it]
#  31%|███▏      | 20/64 [04:46<11:33, 15.77s/it]
#  33%|███▎      | 21/64 [04:52<09:05, 12.68s/it]
#  34%|███▍      | 22/64 [04:54<06:48,  9.73s/it]
#  36%|███▌      | 23/64 [04:55<04:41,  6.87s/it]
#  38%|███▊      | 24/64 [04:59<04:02,  6.07s/it]
#  39%|███▉      | 25/64 [04:59<02:52,  4.42s/it]
#  41%|████      | 26/64 [05:00<01:59,  3.15s/it]
#  42%|████▏     | 27/64 [05:03<02:02,  3.31s/it]
#  44%|████▍     | 28/64 [05:05<01:43,  2.88s/it]
#  45%|████▌     | 29/64 [05:06<01:18,  2.24s/it]
#  47%|████▋     | 30/64 [05:27<04:32,  8.02s/it]
#  48%|████▊     | 31/64 [05:31<03:45,  6.83s/it]
#  50%|█████     | 32/64 [05:54<06:08, 11.53s/it]
#  52%|█████▏    | 33/64 [05:54<04:13,  8.17s/it]
#  53%|█████▎    | 34/64 [05:59<03:30,  7.02s/it]
#  55%|█████▍    | 35/64 [06:18<05:12, 10.77s/it]
#  56%|█████▋    | 36/64 [06:19<03:34,  7.67s/it]
#  58%|█████▊    | 37/64 [06:20<02:33,  5.70s/it]
#  59%|█████▉    | 38/64 [06:20<01:44,  4.04s/it]
#  61%|██████    | 39/64 [06:21<01:19,  3.19s/it]
#  62%|██████▎   | 40/64 [06:22<01:02,  2.60s/it]
#  64%|██████▍   | 41/64 [06:28<01:20,  3.52s/it]
#  66%|██████▌   | 42/64 [06:30<01:04,  2.95s/it]
#  67%|██████▋   | 43/64 [06:30<00:47,  2.25s/it]
#  69%|██████▉   | 44/64 [06:31<00:38,  1.94s/it]
#  70%|███████   | 45/64 [06:32<00:29,  1.56s/it]
#  72%|███████▏  | 46/64 [06:40<01:03,  3.54s/it]
#  73%|███████▎  | 47/64 [06:41<00:48,  2.86s/it]
#  75%|███████▌  | 48/64 [07:00<02:02,  7.63s/it]
#  77%|███████▋  | 49/64 [07:01<01:24,  5.61s/it]
#  78%|███████▊  | 50/64 [07:06<01:14,  5.33s/it]
#  80%|███████▉  | 51/64 [07:16<01:28,  6.83s/it]
#  81%|████████▏ | 52/64 [07:17<01:01,  5.13s/it]
#  83%|████████▎ | 53/64 [07:55<02:44, 14.95s/it]
#  84%|████████▍ | 54/64 [08:03<02:07, 12.72s/it]
#  86%|████████▌ | 55/64 [08:05<01:25,  9.51s/it]
#  88%|████████▊ | 56/64 [08:05<00:54,  6.76s/it]
#  89%|████████▉ | 57/64 [08:07<00:36,  5.17s/it]
#  91%|█████████ | 58/64 [08:08<00:24,  4.04s/it]
#  92%|█████████▏| 59/64 [08:09<00:15,  3.03s/it]
#  94%|█████████▍| 60/64 [08:10<00:10,  2.55s/it]
#  95%|█████████▌| 61/64 [08:12<00:07,  2.41s/it]
#  97%|█████████▋| 62/64 [08:17<00:06,  3.15s/it]
#  98%|█████████▊| 63/64 [08:17<00:02,  2.27s/it]
# 100%|██████████| 64/64 [10:22<00:00, 38.87s/it]

# %% [markdown]
# ## Extract **entities** (for standardization)

# %%
print("Extracting unique entities...")

# %%
entities = set()

for filepath in tqdm(glob(os.path.join(OUTPUT_PATH, 'datapoints/*.csv'))):
    df = pd.read_csv(filepath)
    entities |= set(df['entity'].tolist())

res = pd.DataFrame()
res['name'] = list(entities)
res.sort_values(by='name') \
    .to_csv(os.path.join(STANDARDIZATION_PATH, "entities.csv"), index=False)
# Out:
# 100%|██████████| 13922/13922 [02:40<00:00, 86.68it/s]
