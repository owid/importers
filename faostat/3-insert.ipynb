# %% [markdown]
# # Inserting the CSVs into the database

# %% [markdown]
# ## Dependencies and globals

# %%
import sys
sys.path.append("..")

import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from glob import glob

from db import connection
from db_utils import DBUtils

# ID of user who imported the data
USER_ID = 29

# Dataset namespace
NAMESPACE = 'faostat_2020'

OUTPUT_PATH = 'output/'
STANDARDIZATION_PATH = 'standardization/'

# %% [markdown]
# ## Load datasets, entities, variables & sources

# %%
entities = pd.read_csv(
    os.path.join(STANDARDIZATION_PATH, './entities_standardized.csv'), 
    index_col='name'
)

# %%
db_entity_id_by_name = { 
    row.name: int(row['db_entity_id']) for _, row in entities.iterrows() 
}

# %%
variables = pd.read_csv(os.path.join(OUTPUT_PATH, 'variables.csv'))
datasets = pd.read_csv(os.path.join(OUTPUT_PATH, 'datasets.csv'))
sources = pd.read_csv(os.path.join(OUTPUT_PATH, 'sources.csv'))

# %%
datasets
# Out:
#       id                                               name  \
# 0     AE             ASTI R&D Indicators: ASTI-Expenditures
# 1     AF              ASTI R&D Indicators: ASTI-Researchers
# 2     BC  Food Balance: Commodity Balances - Crops Prima...
# 3     BL  Food Balance: Commodity Balances - Livestock a...
# 4     CC  Food Balance: Food Supply - Crops Primary Equi...
# 5   CISP  Investment: Country Investment Statistics Profile
# 6     CL  Food Balance: Food Supply - Livestock and Fish...
# 7     CS                    Macro-Statistics: Capital Stock
# 8     EF  Agri-Environmental Indicators: Fertilizers ind...
# 9     EI  Agri-Environmental Indicators: Emissions inten...
# 10    EK  Agri-Environmental Indicators: Livestock Patterns
# 11    EL  Agri-Environmental Indicators: Land use indica...
# 12    EM    Agri-Environmental Indicators: Emissions shares
# 13   EMN    Agri-Environmental Indicators: Livestock Manure
# 14    EP  Agri-Environmental Indicators: Pesticides indi...
# 15   FBS                    Food Balance: New Food Balances
# 16  FBSH  Food Balance: Food Balances (old methodology a...
# 17   FDI        Investment: Foreign Direct Investment (FDI)
# 18    FO            Forestry: Forestry Production and Trade
# 19    FS   Food Security: Suite of Food Security Indicators
# 20    GA             Emissions - Agriculture: Crop Residues
# 21    GB   Emissions - Agriculture: Burning - Crop Residues
# 22    GC                     Emissions - Land Use: Cropland
# 23    GE      Emissions - Agriculture: Enteric Fermentation
# 24    GF                  Emissions - Land Use: Forest Land
# 25    GG                    Emissions - Land Use: Grassland
# 26    GH         Emissions - Agriculture: Burning - Savanna
# 27    GI            Emissions - Land Use: Burning - Biomass
# 28    GL               Emissions - Land Use: Land Use Total
# 29    GM         Emissions - Agriculture: Manure Management
# ..   ...                                                ...
# 34    GU   Emissions - Agriculture: Manure applied to Soils
# 35    GV  Emissions - Agriculture: Cultivation of Organi...
# 36    GY     Emissions - Agriculture: Synthetic Fertilizers
# 37    IC                  Investment: Credit to Agriculture
# 38    IG                 Investment: Government Expenditure
# 39    LC          Agri-Environmental Indicators: Land Cover
# 40    MK                 Macro-Statistics: Macro Indicators
# 41    OE                      Inputs: Employment Indicators
# 42    PD                                  Prices: Deflators
# 43    PE                    Prices: Exchange rates - Annual
# 44    PI            Prices: Producer Price Indices - Annual
# 45    PP                   Prices: Producer Prices - Annual
# 46    QA                           Production: Live Animals
# 47    QC                                  Production: Crops
# 48    QD                        Production: Crops processed
# 49    QI                     Production: Production Indices
# 50    QL                      Production: Livestock Primary
# 51    QP                    Production: Livestock Processed
# 52    QV       Production: Value of Agricultural Production
# 53    RA                        Inputs: Fertilizers archive
# 54   RFB                     Inputs: Fertilizers by Product
# 55   RFN                    Inputs: Fertilizers by Nutrient
# 56    RL                                   Inputs: Land Use
# 57    RM                              Investment: Machinery
# 58    RP                             Inputs: Pesticides Use
# 59    RT                           Inputs: Pesticides Trade
# 60    RY                      Investment: Machinery Archive
# 61    TA                                Trade: Live animals
# 62    TI                               Trade: Trade Indices
# 63    TP                Trade: Crops and livestock products
#
#                                           description
# 0   ASTI collects primary time-series data on agri...
# 1   ASTI collects primary time-series data on agri...
# 2   Commodity balances show balances of food and a...
# 3   Food supply data is some of the most important...
# 4   Food supply data is some of the most important...
# 5   The Country Investment Statistics Profile doma...
# 6   Food supply data is some of the most important...
# 7   As part of the FAO Agriculture Capital Stock (...
# 8   The data describe the use of chemical and mine...
# 9   Intensities of greenhouse gas (GHG) emissions ...
# 10  The Livestock Patterns domain of the FAOSTAT A...
# 11  The Agri-environmental IndicatorsLand Use dom...
# 12  The FAOSTAT Emissions shares domain of FAOSTAT...
# 13  The Livestock Manure domain under the FAOSTAT ...
# 14  Agri-environmental indicator on the Use of pes...
# 15  Food Balance Sheet presents a comprehensive pi...
# 16  Food Balance Sheet presents a comprehensive pi...
# 17  All data originates from the United Nations Co...
# 18  The database contains data on the production a...
# 19  For detailed description of the indicators bel...
# 20  Greenhouse gas (GHG) emissions from crop resid...
# 21  Greenhouse Gas (GHG) emissions from burning cr...
# 22  Greenhouse gas (GHG) emissions in the domain "...
# 23  Greenhouse gas (GHG) emissions from enteric fe...
# 24  Annual net CO2 emission/removal from Forest La...
# 25  Greenhouse gas (GHG) emissions in the domain "...
# 26  Greenhouse Gas (GHG) emissions from burning of...
# 27  Greenhouse Gas (GHG) emissions from burning of...
# 28  Land Use Total contains all GHG emissions and ...
# 29  Greenhouse gas (GHG) emissions from manure man...
# ..                                                ...
# 34  GHG emissions from manure applied to soils con...
# 35  The domain Cultivation of Organic soils contai...
# 36  Greenhouse gas (GHG) emissions from synthetic ...
# 37  The Credit to Agriculture dataset provides nat...
# 38  The Statistics Division of FAO collects annual...
# 39  The FAOSTAT domain Land Cover under the Agri-E...
# 40  TheFAOSTAT Macro Indicatorsdatabase provides a...
# 41  The FAOSTAT Employment indicators module conta...
# 42  The FAOSTAT Deflators database provides the fo...
# 43  Annual exchange rates, national currency units...
# 44  Indices of agricultural producer prices that m...
# 45  This sub-domain contains data on Agriculture P...
# 46  The dataset contains the following commodities...
# 47  Crop statistics are recorded for 173 products,...
# 48  The dataset covers the following commodities: ...
# 49  The dataset includes data on gross and net pro...
# 50  The dataset contains the following commodities...
# 51  The dataset covers the following commodities: ...
# 52  The data set includes data on gross and net pr...
# 53  The Fertilizer archive dataset containsinforma...
# 54  The Fertilizers by Product dataset contains in...
# 55  The Fertilizers by Nutrient dataset contains i...
# 56  The FAOSTAT Land Use domain contains data on f...
# 57  Important notice: FAOSTAT database on Agricult...
# 58  The Pesticides Use database includes data on t...
# 59  This domain contains data on pesticides and co...
# 60                                                NaN
# 61  The food and agricultural trade dataset is col...
# 62  The food and agricultural trade dataset is col...
# 63  The food and agricultural trade dataset is col...
#
# [64 rows x 3 columns]

# %% [markdown]
# ## Integrity checks

# %%
def print_err(*args, **kwargs):
    print(*args, file=sys.stderr, **kwargs)

def assert_unique(df, subset, message="Duplicate row found"):
    duplicate_mask = df.duplicated(subset=subset)
    if duplicate_mask.any() == True:
        print_err(message)
        print_err(df[duplicate_mask])
        return 1
    return 0

# %%
print("Running integrity checks...")
# Out:
# Running integrity checks...

# %%
errors = 0

# Dataset IDs should be unique
errors += assert_unique(datasets, ['id'])

# Dataset names should be unique
errors += assert_unique(datasets, ['name'])

# Variable names should be unique
errors += assert_unique(variables, ['name'])

# Variable codes should be unique
errors += assert_unique(variables, ['code'])

# all entities should have a db_entity_id
if entities['db_entity_id'].isnull().any() == True:
    print_err("Entities are missing database ID")
    print_err(entities[entities['db_entity_id'].isnull()])
    errors += 1

# all entities in the data should exist in standardization file
for filepath in tqdm(sorted(glob(os.path.join(OUTPUT_PATH, 'datapoints/*.csv')))):
    df = pd.read_csv(filepath)
    # UNIQUE (entity, year) constraint
    errors += assert_unique(df, ['entity', 'year'], "Duplicate row in %s" % filepath)
    # No empty values
    if df['value'].isnull().any():
        print("%s contains empty values in 'value' column" % filepath)
        errors += 1
    # No non-numeric values
    if not df['value'].map(np.isreal).all():
        print("Non-numeric values in %s" % filepath)
        print(df[pd.to_numeric(df['value'], errors='coerce').isnull()])
        errors += 1

if errors != 0:
    print_err("\nIntegrity checks failed. There were %s errors.\n" % str(errors))
    sys.exit(1)
else:
    print("\nIntegrity checks passed.\n")
# Out:
#   0%|          | 0/14048 [00:00<?, ?it/s]
#   0%|          | 12/14048 [00:00<02:08, 109.30it/s]
#   0%|          | 22/14048 [00:00<02:12, 105.91it/s]
#   0%|          | 31/14048 [00:00<02:21, 98.74it/s]
#   0%|          | 40/14048 [00:00<02:29, 93.58it/s]
#   0%|          | 48/14048 [00:00<02:42, 86.30it/s]
#   0%|          | 58/14048 [00:00<02:38, 88.48it/s]
#   0%|          | 67/14048 [00:00<02:42, 85.95it/s]
#   1%|          | 77/14048 [00:00<02:37, 88.97it/s]
#   1%|          | 89/14048 [00:00<02:27, 94.60it/s]
#   1%|          | 99/14048 [00:01<02:41, 86.37it/s]
#   1%|          | 108/14048 [00:01<02:41, 86.58it/s]
#   1%|          | 117/14048 [00:01<02:39, 87.53it/s]
#   1%|          | 129/14048 [00:01<02:26, 94.89it/s]
#   1%|          | 141/14048 [00:01<02:18, 100.30it/s]
#   1%|          | 152/14048 [00:01<02:18, 100.69it/s]
#   1%|          | 163/14048 [00:01<02:23, 96.82it/s]
#   1%|          | 173/14048 [00:01<02:23, 96.74it/s]
#   1%|▏         | 183/14048 [00:01<02:27, 94.20it/s]
#   1%|▏         | 194/14048 [00:02<02:21, 97.87it/s]
#   1%|▏         | 205/14048 [00:02<02:18, 100.10it/s]
#   2%|▏         | 216/14048 [00:02<02:21, 97.51it/s]
#   2%|▏         | 228/14048 [00:02<02:16, 101.42it/s]
#   2%|▏         | 239/14048 [00:02<02:26, 94.08it/s]
#   2%|▏         | 249/14048 [00:02<02:47, 82.60it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-dca6070534ae> in <module>
#      21 # all entities in the data should exist in standardization file
#      22 for filepath in tqdm(sorted(glob(os.path.join(OUTPUT_PATH, 'datapoints/*.csv')))):
# ---> 23     df = pd.read_csv(filepath)
#      24     # UNIQUE (entity, year) constraint
#      25     errors += assert_unique(df, ['entity', 'year'], "Duplicate row in %s" % filepath)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570
#     571
# --> 572 def is_categorical_dtype(arr_or_dtype):
#     573     """
#     574     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Insert database rows

# %%
with connection as c:
    db = DBUtils(c)
    
    for _, dataset in tqdm(datasets.iterrows(), total=len(datasets)):
        
        # Insert the dataset
        print("Inserting dataset: %s" % dataset['name'])
        db_dataset_id = db.upsert_dataset(
            name=dataset['name'],
            description=dataset['description'],
            namespace=NAMESPACE, 
            user_id=USER_ID)
        
        # Insert the source
        source = sources[sources['dataset_id'] == dataset.id].iloc[0]
        print("Inserting source: %s" % source['name'])
        db_source_id = db.upsert_source(
            name=source['name'], 
            description=source['description'], 
            dataset_id=db_dataset_id)
        
        # Insert variables associated with this dataset
        for j, variable in variables[variables.dataset_id == dataset['id']].iterrows():
            # insert row in variables table
            print("Inserting variable: %s" % variable['name'])
            db_variable_id = db.upsert_variable(
                name=variable['name'], 
                code=variable['code'], 
                unit=variable['unit'], 
                description=variable['description'],
                short_unit=None, 
                source_id=db_source_id, 
                dataset_id=db_dataset_id)

            # read datapoints
            data_values = pd.read_csv(os.path.join(OUTPUT_PATH, 'datapoints', '%s.csv' % variable.id))

            values = [(float(row['value']), int(row['year']), db_entity_id_by_name[row['entity']], db_variable_id)
                      for _, row in data_values.iterrows()]

            print("Inserting values...")
            db.upsert_many("""
                INSERT INTO 
                    data_values (value, year, entityId, variableId)
                VALUES 
                    (%s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE
                    year = VALUES(year)
            """, values)
            
            # We have a dummy ON DUPLICATE handler that updates the year which is essentially 
            # a no update operation. We do this only to avoid a duplicate key error. It occurs 
            # when FAO uses an Item Group and Item with the same name. For example, 'Eggs' is 
            # both an Item Group and a standalone Item in: 
            # Commodity Balances - Livestock and Fish Primary Equivalent
            
            # This is not ideal because we could be masking other duplication issues, we should 
            # ideally have the differentiation between groups and itemsin the database, but this 
            # requires effort and time, both of which are currently in short supply.
            
            print("Inserted %d values for variable" % len(values))

print("All done. Phew!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-13248ca2b4a9> in <module>
# ----> 1 with connection as c:
#       2     db = DBUtils(c)
#       3
#       4     for _, dataset in tqdm(datasets.iterrows(), total=len(datasets)):
#       5
#
# NameError: name 'connection' is not defined

# %% [markdown]
# ## SQL to delete all data

# %% [markdown]
# ```sql
# DELETE data_values
# FROM   data_values
#        INNER JOIN variables
#                ON variables.id = data_values.variableid
#        INNER JOIN sources
#                ON sources.id = variables.sourceid
#        INNER JOIN datasets
#                ON datasets.id = sources.datasetid
# WHERE  datasets.namespace = 'faostat_2020';
#
# DELETE variables
# FROM   variables
#        INNER JOIN sources
#                ON sources.id = variables.sourceid
#        INNER JOIN datasets
#                ON datasets.id = sources.datasetid
# WHERE  datasets.namespace = 'faostat_2020';
#
# DELETE sources
# FROM   sources
#        INNER JOIN datasets
#                ON datasets.id = sources.datasetid
# WHERE  datasets.namespace = 'faostat_2020';
#
# DELETE FROM datasets
# WHERE  namespace = 'faostat_2020';
# ```
